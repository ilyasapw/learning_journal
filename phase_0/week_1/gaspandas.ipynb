# %%
import pandas as pd

# %% [markdown]
# ### Load Data sesuai file ekstensinya

# %%
df_student = pd.read_csv('dataset/StudentsPerformance.csv')

# %%
df_student
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
df.shape
# Out:
# (126314, 23)

# %%
df.head(10)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  ...  win_equiv  opp_id      opp_fran  \
# 0            0     TRH       Huskies  ...  40.294830     NYK        Knicks
# ...

# %%
pd.set_option('display.max_columns', None) # Menampilkan columns yang terlihat, misalnya disembunyikan dalam ...

# %%
df.head(7)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
#
#    is_playoffs team_id   fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH   Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK    Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS     Stags   63  1300.0000  1309.6521  42.012257    NYK
# ...

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.4149  1704.3949
# 126310         102            1     GSW   Warriors  104  1809.9791  1813.6349
# 126311         101            1     CLE  Cavaliers   91  1704.3949  1700.7391
# 126312         102            1     CLE  Cavaliers   97  1700.7391  1692.0859
# 126313         103            1     GSW   Warriors  105  1813.6349  1822.2881
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
#cari tipe data ygy...ahahaha gblog
df.info() #kalo keluar output berlebih, klik in a text editor
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
#data statistik singkat, hanya yang memiliki tipe data integer
df.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %%
df['team_id'].value_counts() #seberapa sering spesifik value muncul pada column sesuai team_id
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
# menampilkan data yang team_id adalah TRH
df.loc[df['team_id'] == 'TRH']
# Out:
#      gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 0            1  194611010TRH   NBA        0     1947   11/1/1946           1
# 10           6  194611030CLR   NBA        1     1947   11/3/1946           2
# 24          13  194611080TRH   NBA        0     1947   11/8/1946           3
# 26          14  194611090CHS   NBA        1     1947   11/9/1946           4
# 49          25  194611150TRH   NBA        0     1947  11/15/1946           5
# 50          26  194611160BOS   NBA        1     1947  11/16/1946           6
# 64          33  194611180PIT   NBA        1     1947  11/18/1946           7
# 69          35  194611190TRH   NBA        0     1947  11/19/1946           8
# 83          42  194611220TRH   NBA        0     1947  11/22/1946           9
# 91          46  194611230WSC   NBA        1     1947  11/23/1946          10
# 104         53  194611260TRH   NBA        0     1947  11/26/1946          11
# ...

# %%
df.loc[df['fran_id']== 'Lakers'].head()
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 1136        569  194811040BLB   NBA        1     1949   11/4/1948           1
# 1152        577  194811060WSC   NBA        1     1949   11/6/1948           2
# 1159        580  194811090BOS   NBA        1     1949   11/9/1948           3
# 1170        586  194811110NYK   NBA        1     1949  11/11/1948           4
# 1183        592  194811130PRO   NBA        1     1949  11/13/1948           5
#
#       is_playoffs team_id fran_id  pts      elo_i      elo_n  win_equiv  \
# 1136            0     MNL  Lakers   84  1527.0000  1542.2545  51.218754
# 1152            0     MNL  Lakers   62  1542.2545  1536.2078  50.621624
# 1159            0     MNL  Lakers   55  1536.2078  1513.4880  48.341133
# 1170            0     MNL  Lakers   77  1513.4880  1524.9596  49.499451
# 1183            0     MNL  Lakers   90  1524.9596  1533.2726  50.330185
#
# ...

# %%
df.loc[df['fran_id']== 'Lakers', 'team_id']
#filter data berdasarakan fran_id yaitu Lakers
#pilih kollom yang mau di itung yaitu team_id
# Out:
# 1136      MNL
# 1152      MNL
# 1159      MNL
# 1170      MNL
# 1183      MNL
#          ...
# 126016    LAL
# 126052    LAL
# 126086    LAL
# 126115    LAL
# 126137    LAL
# Name: team_id, Length: 6024, dtype: object

# %%
df.loc[df['fran_id']== 'Lakers', 'team_id'].value_counts()#dihitung jumlah data dengan value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %% [markdown]
# ### CONTOH LAGI

# %%
df.loc[df['team_id']== 'TRH']
# Out:
#      gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 0            1  194611010TRH   NBA        0     1947   11/1/1946           1
# 10           6  194611030CLR   NBA        1     1947   11/3/1946           2
# 24          13  194611080TRH   NBA        0     1947   11/8/1946           3
# 26          14  194611090CHS   NBA        1     1947   11/9/1946           4
# 49          25  194611150TRH   NBA        0     1947  11/15/1946           5
# 50          26  194611160BOS   NBA        1     1947  11/16/1946           6
# 64          33  194611180PIT   NBA        1     1947  11/18/1946           7
# 69          35  194611190TRH   NBA        0     1947  11/19/1946           8
# 83          42  194611220TRH   NBA        0     1947  11/22/1946           9
# 91          46  194611230WSC   NBA        1     1947  11/23/1946          10
# 104         53  194611260TRH   NBA        0     1947  11/26/1946          11
# ...

# %% [markdown]
# ### TADI KELEWAT SAMPE SINI

# %% [markdown]
# ### QEURY

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df[
    (df['year_id'] > 1950) &
    (df['fran_id'] == 'Knicks') &
    (df['pts'] > 150)
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 9274         4638  195912110NYK   NBA        0     1960  12/11/1959
# 20785       10393  197002130PHI   NBA        1     1970   2/13/1970
# 103990      51996  200612270NYK   NBA        0     2007  12/27/2006
#
#         seasongame  is_playoffs team_id fran_id  pts      elo_i      elo_n  \
# 9274            23            0     NYK  Knicks  152  1455.3502  1481.0966
# 20785           63            0     NYK  Knicks  151  1646.8032  1673.8684
# 103990          31            0     NYK  Knicks  151  1391.4535  1403.1624
#
#         win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 9274    37.764519    SYR   Sixers      121  1594.9003  1569.1539
# 20785   61.501518    PHI   Sixers      106  1523.8624  1496.7972
# 103990  31.006033    DET  Pistons      145  1621.2067  1609.4978
#
#        game_location game_result  forecast notes
# 9274               H           W  0.443327   NaN
# ...

# %%
# CARi team id BLB 
# yang main di tahun 1953
# pts/poin lawan lebih dari 100
# pts/poin lebih dari 100

#JAWAB
df[
    (df['team_id'] == 'BLB') &
    (df['year_id'] == 1953) &
    (df['opp_pts'] > 100 ) &
    (df['pts'] > 100)
]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
#
#       is_playoffs team_id    fran_id  pts      elo_i      elo_n  win_equiv  \
# 4890            0     BLB  Baltimore  126  1328.6687  1356.6470  25.797792
# 4909            0     BLB  Baltimore  104  1349.8323  1346.3594  24.876236
# 5208            0     BLB  Baltimore  107  1284.5239  1282.2396  19.579676
#
#      opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 4890    BOS  Celtics      105  1591.1434  1563.1652             H           W
# 4909    MNL   Lakers      112  1665.4396  1668.9125             H           L
# 5208    NYK   Knicks      113  1649.1516  1651.4359             H           L
#
#       forecast         notes
# ...

# %%
#CARA KEDUA
df.query(" team_id == 'BLB' & year_id == 1953 & opp_pts > 100 & pts > 100 ")
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
#
#       is_playoffs team_id    fran_id  pts      elo_i      elo_n  win_equiv  \
# 4890            0     BLB  Baltimore  126  1328.6687  1356.6470  25.797792
# 4909            0     BLB  Baltimore  104  1349.8323  1346.3594  24.876236
# 5208            0     BLB  Baltimore  107  1284.5239  1282.2396  19.579676
#
#      opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 4890    BOS  Celtics      105  1591.1434  1563.1652             H           W
# 4909    MNL   Lakers      112  1665.4396  1668.9125             H           L
# 5208    NYK   Knicks      113  1649.1516  1651.4359             H           L
#
#       forecast         notes
# ...

# %% [markdown]
# ### GROUPING and Aggregating Data

# %%
df.groupby('fran_id')['pts'].sum()
# Out:
# fran_id
# Baltimore        37219
# Bombers          17793
# Bucks           418326
# Bulls           437269
# Capitols         22387
# Cavaliers       380416
# Celtics         626484
# Clippers        380523
# Colonels         94435
# Condors          49642
# Denver            4818
# Falcons           3797
# Floridians       49568
# Grizzlies       157683
# Hawks           567261
# Heat            229103
# Hornets          84489
# Huskies           3995
# Ironmen           3674
# Jazz            363155
# Jets              4482
# Kings           569245
# Knicks          582497
# Lakers          637444
# Magic           219436
# Mavericks       309239
# Nets            417809
# Nuggets         445780
# Olympians        22864
# Pacers          438288
# Packers           6193
# Pelicans        220794
# Pistons         572758
# Raptors         158370
# Rebels            4474
# Redskins          5372
# Rockets         432504
# Sails            30080
# Sixers          585891
# ...

# %%
df.groupby('fran_id')['pts'].sum().head()
# Out:
# fran_id
# Baltimore     37219
# Bombers       17793
# Bucks        418326
# Bulls        437269
# Capitols      22387
# Name: pts, dtype: int64

# %%
df[
    (df['year_id'] > 2010) &
    (df['fran_id'] == 'Knicks') 
].groupby('year_id')['pts'].sum()
# Out:
# year_id
# 2011    9097
# 2012    6872
# 2013    9259
# 2014    8084
# 2015    7535
# Name: pts, dtype: int64

# %%
df[
    (df['year_id'] > 2010) &
    (df['fran_id'] == 'Knicks') 
].groupby(['year_id','game_location'])['pts'].sum()
# Out:
# year_id  game_location
# 2011     A                4480
#          H                4617
# 2012     A                3420
#          H                3452
# 2013     A                4404
#          H                4753
#          N                 102
# 2014     A                3986
#          H                4098
# 2015     A                3706
#          H                3750
#          N                  79
# Name: pts, dtype: int64

# %%
df[
    (df['year_id'] > 2010) &
    (df['fran_id'] == 'Knicks') 
].groupby(['game_location','year_id'])['pts'].sum()
# Out:
# game_location  year_id
# A              2011       4480
#                2012       3420
#                2013       4404
#                2014       3986
#                2015       3706
# H              2011       4617
#                2012       3452
#                2013       4753
#                2014       4098
#                2015       3750
# N              2013        102
#                2015         79
# Name: pts, dtype: int64

# %% [markdown]
# ### Manipulating Columns
# ## df baru karena semisal kita sebelumnya telah hapus maupun update

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
nba = df.copy() #copy dataframe df

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
nba.drop('elo_i', axis=1) #hapus data, tapi ga permanen, jadi itu yang dikasi liat cuma preview
#cara hapus permanen nba.drop('elo_i', axis=1, inplace=True)
#atau bisa juga dimasukkan variable nba_tanpa_elo_i = nba.drop('elo_i', axis=1, inplace=True)
#jadi kita bisa akses data di nba_tanpa_elo_i

# %%
#rename
nba.rename(columns={'game_location':'location','game_result':'result'})
# masi sama, pake inplace atau masukkan ke variabel baru
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
nba.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %% [markdown]
# ### Hari ke 5 Week 1

# %% [markdown]
# ### Specifying Data Types

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
nba["date_game"] = pd.to_datetime(nba["date_game"]) #ubah tipeda yang sebelumnya object
                                                    # menjadi date time series

# %%
nba['game_location'].nunique() #menampilkan by number nya saja/jumlahnya saja
# Out:
# 3

# %%
nba['game_location'].unique() #ditampilaknkan isinya
# Out:
# array(['H', 'A', 'N'], dtype=object)

# %%
nba['game_location'].value_counts() #ditampilan uniqe isi dan jumlahnya
# Out:
# H    63138
# A    63138
# N       38
# Name: game_location, dtype: int64

# %%
nba['game_location']= pd.Categorical(nba["game_location"])#ubah tipe data game_location to Categorical

# %%
nba['game_location'].dtype # jadi ada kategori A, kategori H, kategori N
# Out:
# CategoricalDtype(categories=['A', 'H', 'N'], ordered=False)

# %%
# kelebihannya memory bisa menurun, setelah ubah ke Categorical
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# ### Missing Value
# ## NaN NotaNumber

# %%
rows_without_missing_data = nba.dropna() #ngikut paling sedikit

# %%
rows_without_missing_data.shape
# Out:
# (5424, 23)

# %%
data_without_missing_columns = nba.dropna(axis=1) #drop by columns
                                                    #ngikut paling banyak

# %%
data_without_missing_columns.shape
# Out:
# (126314, 22)

# %%
data_with_default_notes = nba.copy()

# %%
data_with_default_notes["notes"].fillna(
    value="no notes at all",
    inplace=True
)

# %%
data_with_default_notes["notes"].describe()
# Out:
# count              126314
# unique                232
# top       no notes at all
# freq               120890
# Name: notes, dtype: object

# %% [markdown]
# ## Invalid Values/ anomali/aneh/ga normal/ misal tinggi melebihi 3meter,seharusnya 100-200cm

# %%
nba.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %%
nba[nba["pts"] == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 26684      13343  197210260VIR   ABA        1     1973  10/26/1972
#
#        seasongame  is_playoffs team_id  fran_id  ...  win_equiv  opp_id  \
# 26684           7            0     DNR  Nuggets  ...  40.408863     VIR
#
#        opp_fran  opp_pts  opp_elo_i opp_elo_n  game_location  game_result  \
# 26684   Squires        2  1484.1907  1487.083              A            L
#
#        forecast                           notes
# 26684  0.328948  at Richmond VA; forfeit to VIR
#
# [1 rows x 23 columns]

# %% [markdown]
# ## Visualizing DataFrame

# %%
# import matplotlib.pyplot as plt # Dasarnya
